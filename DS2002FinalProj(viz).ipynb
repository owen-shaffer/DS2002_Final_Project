# %% [markdown]
# <a href="https://colab.research.google.com/github/owen-shaffer/DS2002_Final_Project/blob/main/DS2002FinalProj(viz).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab should save automatically (like Google Docs, etc.), but ensure to click File --> Save before closing out of the tab

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


url = 'https://raw.githubusercontent.com/owen-shaffer/DS2002_Final_Project/main/Crime_Data.csv'

Crime_cville = pd.read_csv(url)

Crime_cville.head(20)
# Out:
#     RecordID                          Offense    IncidentID  BlockNumber  \
# 0          1  Assist Citizen - Mental/TDO/ECO  202400034093        900.0
# 1          2    Larceny - Of Veh Parts/Access  202400034075       1600.0
# 2          3                      Hit and Run  202400034071        900.0
# 3          4               Disorderly Conduct  202400034068        900.0
# 4          5               Lost/FoundProperty  202400034047        700.0
# 5          6                Crisis Assessment  202400034030       1300.0
# 6          7                         Trespass  202400034026        500.0
# 7          8                   Assault Simple  202400034025        900.0
# 8          9                      Hit and Run  202400033979          NaN
# 9         10  Assist Citizen - Mental/TDO/ECO  202400033977        200.0
# 10        11                         Trespass  202400033967       1200.0
# 11        12            Larceny - Shoplifitng  202400033959        200.0
# ...

# %%
crimes = Crime_cville.Offense.unique()
crimes
# Out:
# array(['Assist Citizen - Mental/TDO/ECO', 'Larceny - Of Veh Parts/Access',
#        'Hit and Run', 'Disorderly Conduct', 'Lost/FoundProperty',
#        'Crisis Assessment', 'Trespass', 'Assault Simple',
#        'Larceny - Shoplifitng', 'Larceny - Theft from Building',
#        'Animal Complaint', 'Vandalism', 'Larceny - From Motor Vehicle',
#        'Domestic Disturbance', 'Assist Agency - Backup/Assist',
#        'Misc - Non-Criminal Call', 'Assist Citizen - Medical',
#        'Larceny - All Other', 'Assault Aggravated',
#        'Drug/Narcotics Violation', 'Suspicious Activity',
#        'Forgery/Counterfeiting', 'Assault Intimidation',
#        'Fraud-impersonation', 'Driving Under the Influence',
#        'Shots Fired/Illegal Hunting', 'Accident - w/out Injuries',
#        'Pornography', 'Assist Agency - Arrest/warrant', 'Burglary',
#        'Harassment', 'Sex Offense', 'Juvenile Investigation',
#        'Animal - Bite', 'Robbery - Armed', 'Fraud-credit card',
# ...

# %%
Crime_cville['DateReported'] = pd.to_datetime(Crime_cville['DateReported'])

Cville_2023 = Crime_cville[Crime_cville['DateReported'].dt.year == 2023]

offense_counts_2023 = Cville_2023['Offense'].value_counts()

total_crimes_2023 = len(Cville_2023)
print(f"Total number of crimes in 2023: {total_crimes_2023}")
# Out:
# Total number of crimes in 2023: 5283

# %%
top_20_offenses = offense_counts_2023.head(20)

plt.figure(figsize=(12, 6))
top_20_offenses.plot(kind='bar')
plt.title('Total Number of Each Offense')
plt.xlabel('Offense')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
larceny_crimes = Cville_2023[Cville_2023['Offense'].str.contains('Larceny', case=False, na=False)]
df = pd.DataFrame(larceny_crimes)
df.head()
# Out:
#       RecordID                        Offense    IncidentID  BlockNumber  \
# 4118      4119            Larceny - All Other  202480000006        800.0
# 4119      4120            Larceny - All Other  202300040112        700.0
# 4121      4122            Larceny - All Other  202300040103        700.0
# 4123      4124            Larceny - All Other  202300040092        900.0
# 4126      4127  Larceny - Theft from Building  202300040048        100.0
#
#            StreetName Agency              DateReported  HourReported  \
# 4118         RIDGE ST    CPD 2023-12-31 22:45:42+00:00          1745
# 4119  PROSPECT AVE, F    CPD 2023-12-31 20:50:55+00:00          1550
# 4121         RIDGE ST    CPD 2023-12-31 19:27:43+00:00          1427
# 4123   PRESTON AVE, B    CPD 2023-12-31 15:36:05+00:00          1036
# 4126       MADISON LN    CPD 2023-12-31 01:07:27+00:00          2007
#
#          ReportingOfficer  Month
# 4118     Miller, Tiffany      12
# 4119  Vlasis, Christopher     12
# ...

# %%
url1 = 'https://raw.githubusercontent.com/owen-shaffer/DS2002_Final_Project/main/PartABCrimeOffenses.csv'

Crime_AnnArbor = pd.read_csv(url1)

Crime_AnnArbor.tail()
# Out:
#        CASE_NUM                   CRIME_DESC  CHARGE_CODE  \
# 5946  240000456          THEFT FROM BUILDING         2308
# 5947  230043965  DRIVING UNDER THE INFLUENCE         8041
# 5948  230043965  DRIVING UNDER THE INFLUENCE         8027
# 5949  240001367                    ALL OTHER         3699
# 5950  240001130               SIMPLE ASSAULT         1313
#
#                                             CHARGE_DESC CRIME_PART  \
# 5946  LARCENY - FROM BUILDING (INCLUDES LIBRARY, OFF...          A
# 5947  OPERATING UNDER THE INFLUENCE OF ALCOHOL / LIQ...          B
# 5948  OPERATING W/BLOOD ALCOHOL CONTENT OF .17% OR MORE          B
# 5949                                SEX OFFENSE (OTHER)          B
# 5950  ASSAULT/ BATTERY/SIMPLE (INCL DOMESTIC AND POL...          A
#
#                          ADDRESS       CITY                 DATE  \
# 5946      3600 BLOCK PLYMOUTH RD  ANN ARBOR  2024-01-04 11:40:00
# 5947  800 BLOCK E UNIVERSITY AVE  ANN ARBOR  2023-10-01 22:31:00
# ...

# %%
Crime_AnnArbor['DATE'] = pd.to_datetime(Crime_AnnArbor['DATE'])

AnnArbor_2023 = Crime_AnnArbor[Crime_AnnArbor['DATE'].dt.year == 2023]

offense_counts_2023 = AnnArbor_2023['CATEGORY'].value_counts()

total_crimes_2023 = len(AnnArbor_2023)
print(f"Total number of crimes in 2023: {total_crimes_2023}")
# Out:
# Total number of crimes in 2023: 5838

# %%
AnnArbor_2023.head()
# Out:
#     CASE_NUM                                CRIME_DESC  CHARGE_CODE  \
# 0  230001504                            SIMPLE ASSAULT         1313
# 1  230001517  DESTRUCTION/DAMAGE/VANDALISM OF PROPERTY         2902
# 2  230001583    FALSE PRETENSE/SWINDLE/CONFIDENCE GAME         2699
# 3  230001585                       THEFT FROM BUILDING         2308
# 4  230001456                            SIMPLE ASSAULT         1313
#
#                                          CHARGE_DESC CRIME_PART  \
# 0  ASSAULT/ BATTERY/SIMPLE (INCL DOMESTIC AND POL...          A
# 1       DAMAGE TO PROPERTY - PRIVATE PROPERTY - MDOP          A
# 2                                      FRAUD (OTHER)          A
# 3  LARCENY - FROM BUILDING (INCLUDES LIBRARY, OFF...          A
# 4  ASSAULT/ BATTERY/SIMPLE (INCL DOMESTIC AND POL...          A
#
#                      ADDRESS       CITY                DATE  \
# 0      200 BLOCK N ASHLEY ST  ANN ARBOR 2023-01-12 07:45:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# 1. Bar plot comparing the top 10 crime types in each city
top_10_cville = Cville_2023['Offense'].value_counts().head(10)
top_10_annarbor = AnnArbor_2023['CATEGORY'].value_counts().head(10)

plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
sns.barplot(x=top_10_cville.index, y=top_10_cville.values)
plt.title('Top 10 Crimes in Charlottesville (2023)')
plt.xticks(rotation=45, ha='right')

plt.subplot(1, 2, 2)
sns.barplot(x=top_10_annarbor.index, y=top_10_annarbor.values)
plt.title('Top 10 Crimes in Ann Arbor (2023)')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()


# 2. Pie chart of crime type proportions for each city
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.pie(top_10_cville, labels=top_10_cville.index, startangle=90)
plt.title('Crime Proportions in Charlottesville (2023)')


plt.subplot(1, 2, 2)
plt.pie(top_10_annarbor, labels=top_10_annarbor.index, startangle=90)
plt.title('Crime Proportions in Ann Arbor (2023)')

plt.tight_layout()
plt.show()

# %%
Cville_2023['DateReported'] = pd.to_datetime(Cville_2023['DateReported'])

Cville_2023['Month'] = Cville_2023['DateReported'].dt.month

monthly_crimes = Cville_2023.groupby('Month')['Offense'].count()

plt.figure(figsize=(10, 6))
plt.plot(monthly_crimes.index, monthly_crimes.values, marker='o', linestyle='-')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')
plt.title('Number of Crimes per Month in Charlottesville (2023)')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()
# Out:
# <ipython-input-23-1c46d812ceb3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cville_2023['DateReported'] = pd.to_datetime(Cville_2023['DateReported'])
# <ipython-input-23-1c46d812ceb3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cville_2023['Month'] = Cville_2023['DateReported'].dt.month

# %%
AnnArbor_2023['DATE'] = pd.to_datetime(AnnArbor_2023['DATE'])

AnnArbor_2023['Month'] = AnnArbor_2023['DATE'].dt.month

monthly_crimes_aa = AnnArbor_2023.groupby('Month')['CATEGORY'].count()

plt.figure(figsize=(10, 6))
plt.plot(monthly_crimes_aa.index, monthly_crimes_aa.values, marker='o', linestyle='-')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')
plt.title('Number of Crimes per Month in Ann Arbor (2023)')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()
# Out:
# <ipython-input-33-87f228421bf8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AnnArbor_2023['DATE'] = pd.to_datetime(AnnArbor_2023['DATE'])
# <ipython-input-33-87f228421bf8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AnnArbor_2023['Month'] = AnnArbor_2023['DATE'].dt.month

# %%
larceny_crimes_cville = Cville_2023[Cville_2023['Offense'].str.contains('Larceny', case=False, na=False)]

monthly_larceny_crimes = larceny_crimes_cville.groupby(larceny_crimes_cville['DateReported'].dt.month)['Offense'].count()

plt.figure(figsize=(10, 6))
plt.plot(monthly_larceny_crimes.index, monthly_larceny_crimes.values, marker='o', linestyle='-')
plt.xlabel('Month')
plt.ylabel('Number of Larceny Crimes')
plt.title('Number of Larceny Crimes per Month in Charlottesville (2023)')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %%
larceny_crimes_aa = AnnArbor_2023[AnnArbor_2023['CATEGORY'].str.contains('LARCENY', case=False, na=False)]
df = pd.DataFrame(larceny_crimes_aa)
df.head()

monthly_larceny_crimes_aa = larceny_crimes_aa.groupby(larceny_crimes_aa['DATE'].dt.month)['CATEGORY'].count()

plt.figure(figsize=(10, 6))
plt.plot(monthly_larceny_crimes_aa.index, monthly_larceny_crimes_aa.values, marker='o', linestyle='-')
plt.xlabel('Month')
plt.ylabel('Number of Larceny Crimes')
plt.title('Number of Larceny Crimes per Month in Ann Arbor (2023)')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %%
assault_crimes = Cville_2023[Cville_2023['Offense'].str.contains('Assault', case=False, na=False)]

assault_crimes['Month'] = assault_crimes['DateReported'].dt.month
monthly_assault_counts = assault_crimes.groupby('Month')['Offense'].count()

group1_months = [1, 5, 6, 7, 8]
group2_months = [month for month in range(1, 13) if month not in group1_months]

avg_group1 = monthly_assault_counts[monthly_assault_counts.index.isin(group1_months)].mean()
avg_group2 = monthly_assault_counts[monthly_assault_counts.index.isin(group2_months)].mean()

print(f"Average assault crimes per month without students (Months 1, 5, 6, 7, 8): {avg_group1}")
print(f"Average assault crimes per month with students: {avg_group2}")
# Out:
# Average assault crimes per month without students (Months 1, 5, 6, 7, 8): 43.0
# Average assault crimes per month with students: 49.0
# <ipython-input-30-ddbdaaffb06a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assault_crimes['Month'] = assault_crimes['DateReported'].dt.month

# %%
assault_crimes = AnnArbor_2023[AnnArbor_2023['CATEGORY'].str.contains('Assault', case=False, na=False)]

assault_crimes['Month'] = assault_crimes['DATE'].dt.month
monthly_assault_counts = assault_crimes.groupby('Month')['CATEGORY'].count()

group1_months = [1, 5, 6, 7, 8]
group2_months = [month for month in range(1, 13) if month not in group1_months]

avg_group1 = monthly_assault_counts[monthly_assault_counts.index.isin(group1_months)].mean()
avg_group2 = monthly_assault_counts[monthly_assault_counts.index.isin(group2_months)].mean()

print(f"Average assault crimes per month without students (Months 1, 5, 6, 7, 8): {avg_group1}")
print(f"Average assault crimes per month with students: {avg_group2}")
# Out:
# Average assault crimes per month without students (Months 1, 5, 6, 7, 8): 78.0
# Average assault crimes per month with students: 76.28571428571429
# <ipython-input-38-6ce324b0b276>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assault_crimes['Month'] = assault_crimes['DATE'].dt.month

# %%
#add city column to cville_2023 for increased accuracy in Arc GIS Geocoding
Cville_2023['City'] = 'Charlottesville'
Cville_2023['County'] = 'Albemarle'
Cville_2023['State'] = 'Virginia'
# Out:
# <ipython-input-52-257e95c859ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cville_2023['City'] = 'Charlottesville'
# <ipython-input-52-257e95c859ee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cville_2023['County'] = 'Albemarle'
# <ipython-input-52-257e95c859ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
Cville_2023.head(1)
# Out:
#       RecordID              Offense    IncidentID  BlockNumber StreetName  \
# 4118      4119  Larceny - All Other  202480000006        800.0   RIDGE ST
#
#      Agency              DateReported  HourReported  ReportingOfficer  Month  \
# 4118    CPD 2023-12-31 22:45:42+00:00          1745  Miller, Tiffany      12
#
#                  City     County     State
# 4118  Charlottesville  Albemarle  Virginia

# %%
# prompt: Download the Cville_2023 and AnnArbor_2023 dataframes in csv format

Cville_2023.to_csv('Cville_2023.csv', index=False)
AnnArbor_2023.to_csv('AnnArbor_2023.csv', index=False)

# %%
Cville_2023.count()
# Out:
# RecordID            5283
# Offense             5283
# IncidentID          5283
# BlockNumber         4868
# StreetName          5283
# Agency              5283
# DateReported        5283
# HourReported        5283
# ReportingOfficer    5282
# Month               5283
# City                5283
# County              5283
# State               5283
# dtype: int64

# %%
AnnArbor_2023.count()
# Out:
# CASE_NUM       5838
# CRIME_DESC     5838
# CHARGE_CODE    5838
# CHARGE_DESC    5838
# CRIME_PART     5838
# ADDRESS        5838
# CITY           5838
# DATE           5838
# CATEGORY       5838
# POINT_X        5838
# POINT_Y        5838
# dtype: int64

# %% [markdown]
# Storing in MongoDB

# %%
#Install needed libraries

# !pip install --upgrade pymongo certifi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 42.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 22.0 MB/s eta 0:00:00
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://mxr9ru:FlameRhino12@cluster1.vnbfb.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
#Set names and save charlottesville data
db = client['Crime_Data']
collection = db['Cville_2023']

data = Cville_2023.to_dict(orient="records")
result = collection.insert_many(data)

# %%
#Set names and save Ann Arbor data
collection2 = db['AnnArbor_2023']

data = AnnArbor_2023.to_dict(orient="records")
result = collection2.insert_many(data)

# %% [markdown]
# Saving to google cloud

# %%
#Install libraries
# !pip install google-cloud-storage

# %%
#Setting up the key
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/GoogleKey.json"

from google.cloud import storage

# %%
bucket_name = "ds_final_project"
cville_file_name = "/content/Cville_2023.csv"
cville_destination_blob_name = "data/Cville_2023.csv"

Ann_Arbor_file_name = "/content/AnnArbor_2023.csv"
annarbor_destination_blob_name = "data/AnnArbor_2023.csv"


def upload_to_gcs(bucket_name, source_file_name, destination_blob_name):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(source_file_name)

upload_to_gcs(bucket_name, cville_file_name, cville_destination_blob_name)
upload_to_gcs(bucket_name, Ann_Arbor_file_name, annarbor_destination_blob_name)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-21-6277bc95f62b> in <cell line: 15>()
#      13     blob.upload_from_filename(source_file_name)
#      14
# ---> 15 upload_to_gcs(bucket_name, cville_file_name, cville_destination_blob_name)
#      16 upload_to_gcs(bucket_name, Ann_Arbor_file_name, annarbor_destination_blob_name)
#
# <ipython-input-21-6277bc95f62b> in upload_to_gcs(bucket_name, source_file_name, destination_blob_name)
#       8
#       9 def upload_to_gcs(bucket_name, source_file_name, destination_blob_name):
# ---> 10     client = storage.Client()
#      11     bucket = client.bucket(bucket_name)
#      12     blob = bucket.blob(destination_blob_name)
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/storage/client.py in __init__(self, project, credentials, _http, client_info, client_options, use_auth_w_custom_endpoint)
# ...

# %%
df['ArrestDatetime'] = pd.to_datetime(df['ArrestDatetime'])


df['Date'] = df['ArrestDatetime'].dt.date
df['Year-Month'] = df['ArrestDatetime'].dt.to_period('M').astype(str)
df['Hour'] = df['ArrestDatetime'].dt.hour
df['Weekday'] = df['ArrestDatetime'].dt.day_name()

crime_counts_by_month = df.groupby('Year-Month').size()
crime_counts_by_month = df.groupby('Year-Month').size().reset_index(name='Crime Count')

print(crime_counts_by_month)

# %%
crime_counts_by_month.plot(kind='bar', figsize=(8, 6))
plt.title('Crimes per Month')
plt.xlabel('Date')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid")
ax = sns.lineplot(data=crime_counts_by_month, x='Year-Month', y='Crime Count', marker='o')


ax.set_title('Larceny Crimes Per Month', fontsize=16)
ax.set_xlabel('Year-Month', fontsize=12)
ax.set_ylabel('Number of Crimes', fontsize=12)
plt.xticks(rotation=45)


ax.set_xticks(ax.get_xticks()[::6])

plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")

# Create the time series plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_crime, x='year_month', y='crime_count', marker='o')

# Add titles and labels
plt.title("Crimes by Month", fontsize=16)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Number of Crimes", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# prompt: give me a graph with the number of each catagory of crime on the x axis

import matplotlib.pyplot as plt

# Assuming 'cvillecrimes' DataFrame is already loaded as in the provided code.

crime_counts = cvillecrimes['Offense'].value_counts()

plt.figure(figsize=(12, 6))
crime_counts.plot(kind='bar')
plt.title('Number of Crimes by Category')
plt.xlabel('Crime Category')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Transforming dates to have month, day, year columns and get rid of the time for cville data

df_2023['Month'] = df_2023['DateReported'].dt.month
df_2023['Day'] = df_2023['DateReported'].dt.day
df_2023['Year'] = df_2023['DateReported'].dt.year
